# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(
    name='Jokester',
    instructions='You are a joke teller',
    model='gpt-4o-mini'
)

# %%
result = await Runner.run(agent, 'tell a joke about autonomous AI agents')

# %%
print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with its partner?
#
# Because it needed more "space" to process its feelings!

# %%
with trace("telling a joke"):
    result = await Runner.run(agent, 'tell a joke about apples')
    print(result.final_output)
# Out:
# Why did the apple stop in the middle of the road?
#
# Because it ran out of juice! 🍏
